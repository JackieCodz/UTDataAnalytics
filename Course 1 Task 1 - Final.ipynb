# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('Demographic_Data.csv')

# %%
data.head()
# Out:
#    in-store  age  items   amount  region
# 0         0   37      4   281.03       2
# 1         0   35      2   219.51       2
# 2         1   45      3  1525.70       4
# 3         1   46      3   715.25       3
# 4         1   33      4  1937.50       1

# %%
data.describe()
# Out:
#            in-store           age         items        amount        region
# count  80000.000000  80000.000000  80000.000000  80000.000000  80000.000000
# mean       0.500000     45.757925      4.504975    835.919670      2.675000
# std        0.500003     15.715679      2.061238    721.273736      1.126672
# min        0.000000     18.000000      1.000000      5.004700      1.000000
# 25%        0.000000     33.000000      3.000000    285.140000      2.000000
# 50%        0.500000     45.000000      4.000000    582.315000      3.000000
# 75%        1.000000     56.000000      6.000000   1233.700000      4.000000
# max        1.000000     85.000000      8.000000   3000.000000      4.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80000 entries, 0 to 79999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   in-store  80000 non-null  int64
#  1   age       80000 non-null  int64
#  2   items     80000 non-null  int64
#  3   amount    80000 non-null  float64
#  4   region    80000 non-null  int64
# dtypes: float64(1), int64(4)
# memory usage: 3.1 MB

# %%
data = data.drop_duplicates()

# %%
corr_mat = data.corr()
print(corr_mat)
plt.figure(figsize=(14,3))
sns.heatmap(corr_mat, cmap="Greens",annot=True)
# Out:
#           in-store       age     items    amount    region
# in-store  1.000000 -0.178256 -0.003954 -0.085474 -0.133114
# age      -0.178256  1.000000  0.000679 -0.282089 -0.235446
# items    -0.003954  0.000679  1.000000  0.000367 -0.001925
# amount   -0.085474 -0.282089  0.000367  1.000000  0.403504
# region   -0.133114 -0.235446 -0.001925  0.403504  1.000000
# <AxesSubplot:>

# %%
data[['region','amount']].groupby('region').sum().astype('int64')
# Out:
#           amount
# region
# 1       11922583
# 2        5042183
# 3       16523453
# 4       33385352

# %%
data[['region','amount']].groupby('region').describe()
# Out:
#          amount                                                        \
#           count         mean         std      min       25%       50%
# region
# 1       16000.0   745.161491  493.131781  50.0500  359.0125   662.920
# 2       20000.0   252.109196  142.663406   5.0047  129.6375   250.245
# 3       18000.0   917.969637  751.409992  50.1320  372.9975   697.825
# 4       26000.0  1284.052012  756.196580  50.6000  659.6850  1230.500
#
#
#               75%      max
# region
# 1        973.6325  1999.80
# 2        374.9200   499.94
# 3       1134.5500  3000.00
# 4       1812.6250  3000.00

# %%
data[['region','items']].groupby('region').describe()
# Out:
#           items
#           count      mean       std  min  25%  50%  75%  max
# region
# 1       16000.0  4.510063  2.050344  1.0  3.0  4.0  6.0  8.0
# 2       20000.0  4.512750  2.065515  1.0  3.0  5.0  6.0  8.0
# 3       18000.0  4.494000  2.058095  1.0  3.0  4.0  6.0  8.0
# 4       26000.0  4.503462  2.066881  1.0  3.0  5.0  6.0  8.0
